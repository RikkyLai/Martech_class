# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
train_file = 'train_sample.csv'
test_file = 'test_sample.csv'
train_data = pd.read_csv(train_file)
test_data = pd.read_csv(test_file)

# %%
index_col = ['Unnamed: 0', 'id', 'click', 'hour', 'C1', 'banner_pos', 'site_id',
       'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category',
       'device_id', 'device_ip', 'device_model', 'device_type',
       'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20',
       'C21']

# %%
print(train_data.columns)
print(test_data.columns)
train_data.head()
# Out:
# Index(['Unnamed: 0', 'id', 'click', 'hour', 'C1', 'banner_pos', 'site_id',
#        'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category',
#        'device_id', 'device_ip', 'device_model', 'device_type',
#        'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20',
#        'C21'],
#       dtype='object')
# Index(['Unnamed: 0', 'id', 'hour', 'C1', 'banner_pos', 'site_id',
#        'site_domain', 'site_category', 'app_id', 'app_domain', 'app_category',
#        'device_id', 'device_ip', 'device_model', 'device_type',
#        'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20',
#        'C21'],
#       dtype='object')
#    Unnamed: 0                    id  click      hour    C1  banner_pos  \
# 0           0   1000009418151094273      0  14102100  1005           0
# 1           1  10000169349117863715      0  14102100  1005           0
# 2           2  10000371904215119486      0  14102100  1005           0
# ...

# %%
col_counts = []
for col in index_col:
    col_counts.append(train_data[col].value_counts())
print(col_counts)
# Out:
# [2047    1
# 9518    1
# 7481    1
# 5432    1
# 9526    1
# 3379    1
# 1330    1
# 7473    1
# 5424    1
# 3371    1
# 3387    1
# 1322    1
# 7465    1
# 5416    1
# 9510    1
# 3363    1
# 1314    1
# 7457    1
# 1338    1
# 9534    1
# 7641    1
# 9550    1
# 7513    1
# 5464    1
# 9558    1
# 3411    1
# 1362    1
# 7505    1
# 5456    1
# 3403    1
#        ..
# 645     1
# 8833    1
# 6830    1
# 4735    1
# 6782    1
# 637     1
# 2684    1
# 8825    1
# 4727    1
# 6774    1
# 4751    1
# 8849    1
# 2708    1
# 661     1
# 685     1
# 2732    1
# 8873    1
# 4775    1
# 6822    1
# 677     1
# 2724    1
# 8865    1
# 4767    1
# 6814    1
# 669     1
# 2716    1
# 8857    1
# 4759    1
# 6806    1
# 0       1
# Name: Unnamed: 0, Length: 10000, dtype: int64, 11147597703567407473    1
# 1081666973895075890     1
# 10714771633334978314    1
# 10263094582844089596    1
# 10758300134640900475    1
# 10579574120486865992    1
# 10798392649530250540    1
# ...

# %%
# train_data和test_data的特征范围不匹配，用不了labelEncoder来将特征值弄到同一个范围，也就难以用 LR
feature_train = train_data.columns.drop(['Unnamed: 0', 'id', 'click', 'hour'])

lbe_list = []
train_x = train_data[feature_train]
train_y = train_data['click']

test_x = test_data[feature_train]
# test_y = test_data['click']
# for feature in feature_train:
#     lbe = LabelEncoder()
#     train_x[feature] = lbe.fit_transform(train_x[feature])
#     test_x[feature] = lbe.transform(test_x[feature])
#     lbe_list.append(lbe)

# %%
from sklearn import tree
cart = tree.DecisionTreeClassifier()
cart.fit(train_x, train_y)
predict_y = cart.predict(test_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-35b4f9752235> in <module>()
#       1 from sklearn import tree
#       2 cart = tree.DecisionTreeClassifier()
# ----> 3 cart.fit(train_x, train_y)
#       4 predict_y = cart.predict(test_x)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# ...
